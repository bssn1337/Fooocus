# %% [markdown]
# # Fooocus — Inpaint & Outpaint Only
# **Model: Juggernaut XL v9** — Clean version, only Inpaint & Outpaint
#
# ### Cara pakai:
# 1. Runtime → Change runtime type → **T4 GPU**
# 2. Jalankan cell di bawah
# 3. Klik link **gradio.live** yang muncul di output

# %%
# ============================================================
# Fooocus Inpaint & Outpaint - Colab Setup
# ============================================================

# Fix numpy + CuPy conflict
# !pip install numpy==1.26.4 --force-reinstall -q
# !pip uninstall cupy-cuda12x cupy -y -q 2>/dev/null || true

# Pindah ke /content dulu sebelum hapus folder lama
# %cd /content
# !rm -rf /content/Fooocus

# Clone custom Fooocus (versi terbaru)
# !git clone https://github.com/bssn1337/Fooocus.git /content/Fooocus

# %cd /content/Fooocus

# Launch - disable-prompt-expansion mencegah auto-tambah konten tidak diinginkan
# !python entry_with_update.py --share --always-high-vram --preset default --disable-prompt-expansion
